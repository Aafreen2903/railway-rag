# %%
# !pip install -U langchain langchain-community langchain-google-genai chromadb pypdf python-docx sentence-transformers
# Out:
# Requirement already satisfied: langchain in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (1.2.1)
# Requirement already satisfied: langchain-community in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-google-genai in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (4.1.3)
# Requirement already satisfied: chromadb in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (1.4.0)
# Requirement already satisfied: pypdf in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (6.5.0)
# Requirement already satisfied: python-docx in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (1.2.0)
# Requirement already satisfied: sentence-transformers in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (5.2.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain) (1.2.6)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.6.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.10.0)
# Requirement already satisfied: certifi in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from langchain-google-genai) (1.56.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.45.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.47.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.6.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.40.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from chromadb) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from python-docx) (6.0.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: filelock in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.12.0)
# Requirement already satisfied: pyproject_hooks in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.28.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\.conda\envs\railway-rag\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyCnmlWHnf-f3DxyPHmN4Qa8KB9M6_1dYQM"

# %%
from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader
import os

documents = []
data_path = "data"

for file in os.listdir(data_path):
    path = os.path.join(data_path, file)

    if file.endswith(".pdf"):
        documents.extend(PyPDFLoader(path).load())

    elif file.endswith(".docx"):
        documents.extend(Docx2txtLoader(path).load())

print("Documents loaded:", len(documents))
# Out:
# Documents loaded: 4

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=150
)

chunks = text_splitter.split_documents(documents)

print("Total chunks created:", len(chunks))
# Out:
# Total chunks created: 4

# %%
for i, doc in enumerate(documents[:5]):
    
    print(f"Doc {i} length:", len(doc.page_content))
# Out:
# Doc 0 length: 607
# Doc 1 length: 430
# Doc 2 length: 434
# Doc 3 length: 409

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

print("Local embeddings ready")
# Out:
# Local embeddings ready

# %%
from langchain_community.vectorstores import Chroma

vector_db = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory="db"
)

vector_db.persist()
print("Vector DB created")
# Out:
# Vector DB created

# %%
retriever = vector_db.as_retriever(search_kwargs={"k": 4})
print("Retriever ready")
# Out:
# Retriever ready

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    temperature=0.2
)

print("Gemini LLM ready")
# Out:
# Gemini LLM ready

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    template="""
You are a Railway Passenger Process Explainer Bot.

Answer ONLY using the provided context.
Do NOT book tickets.
Do NOT give live schedules.
If not found, say:
"Information not available in the provided documents."

Context:
{context}

Question:
{question}

Answer:
""",
    input_variables=["context", "question"]
)

# %%
retriever = vector_db.as_retriever(search_kwargs={"k": 4})
print("Retriever ready")
# Out:
# Retriever ready

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
rag_chain = (
    {
        "context": retriever | format_docs,
        "question": RunnablePassthrough()
    }
    | prompt
    | llm
    | StrOutputParser()
)

print("RAG pipeline ready")
# Out:
# RAG pipeline ready

# %%
answer = rag_chain.invoke(
    "What are the rules for changing boarding point?"
)

print(answer)
# Out:
# Based on the provided guidelines, the rules for changing the boarding point are:
#
# 1. **Refund Policy:** If the boarding station is changed within 24 hours of departure, no refund is allowed except in exceptional cases such as train cancellation, coach non-attachment, or a delay beyond 3 hours.
# 2. **Boarding Rights:** After changing the boarding station, the passenger loses the right to board from the original station. Unauthorized boarding from the original station attracts fare and penalty.
# 3. **Restrictions:** A boarding point change is not allowed if:
#    - The ticket is seized.
#    - The PNR has the VIKALP option.
#    - The ticket is an I-Ticket.
#    - The ticket is a current booking.
# 4. **Additional Changes:** If the boarding station was changed at the time of booking, one more change is allowed via the "Booked Ticket History" section.
